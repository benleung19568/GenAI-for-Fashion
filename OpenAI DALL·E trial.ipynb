# %%
# !pip install openai
# !pip install requests
# !pip install pillow

# %%
import os
import openai
openai.organization = "org-MFjordcY2YAUPCHpUSCcZWoy"
#OPENAI_API_KEY ='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'
os.environ['OPENAI_API_KEY'] = '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'
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.Model.list()
# Out:
# <OpenAIObject list at 0x2017755aa20> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "text-search-babbage-doc-001",
#       "object": "model",
#       "created": 1651172509,
#       "owned_by": "openai-dev",
#       "permission": [
#         {
#           "id": "modelperm-s9n5HnzbtVn7kNc5TIZWiCFS",
#           "object": "model_permission",
#           "created": 1695933794,
#           "allow_create_engine": false,
#           "allow_sampling": true,
#           "allow_logprobs": true,
#           "allow_search_indices": true,
#           "allow_view": true,
#           "allow_fine_tuning": false,
#           "organization": "*",
#           "group": null,
#           "is_blocking": false
#         }
#       ],
#       "root": "text-search-babbage-doc-001",
#       "parent": null
#     },
#     {
#       "id": "curie-search-query",
#       "object": "model",
#       "created": 1651172509,
#       "owned_by": "openai-dev",
#       "permission": [
#         {
# ...

# %%
response = openai.Image.create(
    prompt=" (((Asian woman with blond hair))), (((woman playing piano at the garden))), ((evening vibes colour tone)), Scenic portrait, masterpiece, best quality, ultra highres, 8K resolution, realistic, ultra-detailed, clear image,  good contrast, raw photo, even and flat, even evening lighting",
    n=2,
    size="1024x1024"
)

image_url1 = response['data'][0]['url']
image_url2 = response['data'][1]['url']
print(image_url1)
print(image_url2)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-MFjordcY2YAUPCHpUSCcZWoy/user-x0csvKu4HwUQc2Ptd8qTBd8W/img-C2lNenPxg0mgjL8enVROGsb9.png?st=2023-10-16T14%3A59%3A25Z&se=2023-10-16T16%3A59%3A25Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-16T13%3A54%3A12Z&ske=2023-10-17T13%3A54%3A12Z&sks=b&skv=2021-08-06&sig=R2cXa8OxvUpIE2e5Jn/My87EAaLF42QzAg0G4tvFmfc%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-MFjordcY2YAUPCHpUSCcZWoy/user-x0csvKu4HwUQc2Ptd8qTBd8W/img-XXbzaD71v9JmlBds50SOWlFj.png?st=2023-10-16T14%3A59%3A25Z&se=2023-10-16T16%3A59%3A25Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-16T13%3A54%3A12Z&ske=2023-10-17T13%3A54%3A12Z&sks=b&skv=2021-08-06&sig=P8gnFo0BkhqJEtQSzhf7QrbvAuZDnx2TCyItIyVVwxI%3D

# %%
import PIL
from PIL import Image
import matplotlib.pyplot as plt

print(image_url1)

# Retrieving the resource located at the URL
# and storing it in the file name a.png
urllib.request.urlretrieve(image_url1, "C:/Users/benle/Desktop/Pattern editing/"+"DALLE_test4.png")
urllib.request.urlretrieve(image_url2, "C:/Users/benle/Desktop/Pattern editing/"+"DALLE_test5.png")

# Opening the image and displaying it (to confirm its presence)
img1 = Image.open("C:/Users/benle/Desktop/Pattern editing/"+"DALLE_test4.png")
plt.imshow(img1)

img2 = Image.open("C:/Users/benle/Desktop/Pattern editing/"+"DALLE_test5.png")
plt.imshow(img2)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-MFjordcY2YAUPCHpUSCcZWoy/user-x0csvKu4HwUQc2Ptd8qTBd8W/img-lXklzdWC7CW34uCc2wmrTAcU.png?st=2023-07-12T03%3A33%3A11Z&se=2023-07-12T05%3A33%3A11Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-11T21%3A30%3A18Z&ske=2023-07-12T21%3A30%3A18Z&sks=b&skv=2021-08-06&sig=tXmqzAsFv5oMZyP4oJ16J4XZoDES16zsEXjvx8LF7uk%3D
